# %% [markdown]
# # David Ordóñez Vivar

# %% [markdown]
# Instrucciones
#
# Use one of the student networks on the repository (which was not generated by your group) and plot it using networkX.
# Produce a brief project outline:
#
#    + Describe use case and why social analysis is relevant (e.g.: what you would like to achieve).
#
#    + Describe the methodology.
#
#    + Briefly comment on the results.
#
#    + Use 0.5 – 1 page.
#
# Notes:
#
# If you choose to deliver just a notebook, don't forget to make extensive comments, incuding a brief interpretation of the results.
#
# You can tweak the graph options, to make it more legible or nicer looking (e.g.: colors, edge thickness).
#
# Reference:
#
# https://networkx.github.io/documentation/stable/reference/drawing.html

# %% [markdown]
# ### Use case

# %% [markdown]
# In a company, you can connect your employees with each other by means of communication flows, e.g. e-mails and chats, shared projects and/or shared offices. We can create a network of employees which we can analyze to discover who your most pivotal or connected employees are. This might guide HR in their firing policies, change management and project management.

# %%
import networkx.generators.small
import networkx as net
import matplotlib.pyplot as plt
from random import random
import matplotlib.pyplot as plot
bus=net.read_pajek("BUS.net")
colors = [(random(), random(), random()) for _i in range(bus.number_of_nodes())]

# %%
net.draw(bus,  with_labels = True, node_color=colors, font_weight='bold')
plot.show()
# Out:
# C:\Users\david\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %% [markdown]
# With this result we can see that there are some people on this group that are more conected with other people inside the group, in termns of sitting in a bus together, as it could be number 2 and also there are some people that are less conected in this termns with people in this group, as it could be number 1.
